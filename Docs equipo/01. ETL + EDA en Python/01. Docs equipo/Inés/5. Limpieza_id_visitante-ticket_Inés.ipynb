# %% [markdown]
# ## 1- Importación y lectura del df

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('/content/id_visitante-ticket.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-100227035c4a> in <cell line: 0>()
# ----> 1 df = pd.read_json('/content/id_visitante-ticket.json')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# -> 1025                     obj = self._get_object_parser(self.data)
#    1026                 if self.dtype_backend is not lib.no_default:
#    1027                     return obj.convert_dtypes(
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#    1049         obj = None
#    1050         if typ == "frame":
# -> 1051             obj = FrameParser(json, **kwargs).parse()
#    1052
#    1053         if typ == "series" or obj is None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in parse(self)
#    1185     @final
#    1186     def parse(self):
# -> 1187         self._parse()
#    1188
#    1189         if self.obj is None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in _parse(self)
#    1400
#    1401         if orient == "columns":
# -> 1402             self.obj = DataFrame(
#    1403                 ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404             )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# --> 503     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     504
#     505
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112         # figure out the index, if necessary
#     113         if index is None:
# --> 114             index = _extract_index(arrays)
#     115         else:
#     116             index = ensure_index(index)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     675         lengths = list(set(raw_lengths))
#     676         if len(lengths) > 1:
# --> 677             raise ValueError("All arrays must be of the same length")
#     678
#     679         if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
#Como no puedo abrirlo con pandas, abro el archivo de esta forma para poder verlo.
#Confirmamos que lo que tenemos es un diccionario
import json
with open('id_visitante-ticket.json', 'r', encoding="utf-8") as file:
    data = json.load(file)

type(data)
# Out:
# dict

# %%
#Para convertirlo en dataframe, vamos a hacer un bucle. Hacemos un primer bucle para las claves, y luego un segundo para las listas dentro del valor del diccionario.

datos = []

for id, tablas in data.items():
  for tabla in tablas:
    tabla['id'] = int(id)
    datos.append (tabla)

datos
# Out:
# [{'t_id': 'Training_10118481.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 14.003708207777139,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_15361067.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.900902400347054,
#   'antelacion_de_compra': 2,
#   'id': 3},
#  {'t_id': 'Training_16232328.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 12.638039216497997,
#   'antelacion_de_compra': 218,
#   'id': 3},
#  {'t_id': 'Training_27705571.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.491775434247742,
#   'antelacion_de_compra': 39,
#   'id': 3},
#  {'t_id': 'Training_63766171.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.23345770113666,
#   'antelacion_de_compra': 135,
#   'id': 3},
#  {'t_id': 'Training_66555113.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.404800499782606,
#   'antelacion_de_compra': 75,
#   'id': 3},
#  {'t_id': 'Training_81499267.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 27.838383863563397,
#   'antelacion_de_compra': 198,
#   'id': 3},
#  {'t_id': 'Training_94007493.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 20.05474307387698,
#   'antelacion_de_compra': 273,
#   'id': 3},
#  {'t_id': 'Training_12950225.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 25.96935205631775,
#   'antelacion_de_compra': 357,
#   'id': 3},
#  {'t_id': 'Training_42955258.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 11.373023657347368,
#   'antelacion_de_compra': 72,
#   'id': 3},
#  {'t_id': 'Training_50338135.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 26.209559271482156,
#   'antelacion_de_compra': 122,
#   'id': 3},
#  {'t_id': 'Training_65820611.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.23047520322704,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_8397060.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.943190078954323,
#   'antelacion_de_compra': 3,
#   'id': 3},
#  {'t_id': 'Training_90069123.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 27.116167653135527,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_28136915.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.258440861336084,
#   'antelacion_de_compra': 248,
#   'id': 3},
#  {'t_id': 'Training_52516519.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 24.253906395068036,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_61794811.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 13.299453234113894,
#   'antelacion_de_compra': 159,
#   'id': 3},
#  {'t_id': 'Training_66142455.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 15.092083746634827,
#   'antelacion_de_compra': 181,
#   'id': 3},
#  {'t_id': 'Training_72798447.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.769333135135504,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_78245467.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 11.106088469717612,
#   'antelacion_de_compra': 123,
#   'id': 3},
#  {'t_id': 'Training_83065372.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 11.643214779469597,
#   'antelacion_de_compra': 12,
#   'id': 3},
#  {'t_id': 'Training_87355987.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 18.957712386138848,
#   'antelacion_de_compra': 1,
#   'id': 3},
#  {'t_id': 'Training_88196061.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 17.15280760794055,
#   'antelacion_de_compra': 280,
#   'id': 3},
#  {'t_id': 'Training_29363112.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 8.301612916136905,
#   'antelacion_de_compra': 36,
#   'id': 3},
#  {'t_id': 'Training_36501565.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 22.249491668537242,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_53284079.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 25.109256785308922,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'Training_53305606.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 22.619332199689474,
#   'antelacion_de_compra': 214,
#   'id': 3},
#  {'t_id': 'Training_20716064.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 12.288869596598254,
#   'antelacion_de_compra': 309,
#   'id': 3},
#  {'t_id': 'Training_61325993.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 15.072903288771906,
#   'antelacion_de_compra': 172,
#   'id': 3},
#  {'t_id': 'Training_61564918.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 25.52228122582886,
#   'antelacion_de_compra': 2,
#   'id': 3},
#  {'t_id': 'Training_75082078.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 17.05655867763243,
#   'antelacion_de_compra': 183,
#   'id': 3},
#  {'t_id': 'PublicTest_43074366.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.508845426998061,
#   'antelacion_de_compra': 0,
#   'id': 3},
#  {'t_id': 'PublicTest_28123281.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 16.242386687660233,
#   'antelacion_de_compra': 1,
#   'id': 3},
#  {'t_id': 'PublicTest_75651978.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 8.924983346329569,
#   'antelacion_de_compra': 73,
#   'id': 3},
#  {'t_id': 'PrivateTest_92593957.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 17.345897876913025,
#   'antelacion_de_compra': 165,
#   'id': 3},
#  {'t_id': 'PrivateTest_98556225.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 3.4271605507771383,
#   'antelacion_de_compra': 334,
#   'id': 3},
#  {'t_id': 'Training_10120469.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 13.794902548550668,
#   'antelacion_de_compra': 113,
#   'id': 4},
#  {'t_id': 'Training_15848209.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 9.652370583348272,
#   'antelacion_de_compra': 68,
#   'id': 4},
#  {'t_id': 'Training_19226789.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 23.302232116539297,
#   'antelacion_de_compra': 329,
#   'id': 4},
#  {'t_id': 'Training_2729866.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.87855006853796,
#   'antelacion_de_compra': 251,
#   'id': 4},
#  {'t_id': 'Training_2978709.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 23.309342552160004,
#   'antelacion_de_compra': 317,
#   'id': 4},
#  {'t_id': 'Training_50449072.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.060325318373074,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'Training_59169722.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.155618075645855,
#   'antelacion_de_compra': 340,
#   'id': 4},
#  {'t_id': 'Training_72552568.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 20.91247241675045,
#   'antelacion_de_compra': 220,
#   'id': 4},
#  {'t_id': 'Training_8911067.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.043518366434611,
#   'antelacion_de_compra': 46,
#   'id': 4},
#  {'t_id': 'Training_19237812.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 25.287416109422004,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'Training_37488451.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 9.671369908715063,
#   'antelacion_de_compra': 279,
#   'id': 4},
#  {'t_id': 'Training_4879752.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 14.938078316931946,
#   'antelacion_de_compra': 57,
#   'id': 4},
#  {'t_id': 'Training_94085355.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 20.33534310360165,
#   'antelacion_de_compra': 2,
#   'id': 4},
#  {'t_id': 'Training_99751984.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.669856160040826,
#   'antelacion_de_compra': 327,
#   'id': 4},
#  {'t_id': 'Training_20208912.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.60535928281564,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'Training_21243772.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 13.798008893574437,
#   'antelacion_de_compra': 210,
#   'id': 4},
#  {'t_id': 'Training_30113079.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.207126104999197,
#   'antelacion_de_compra': 311,
#   'id': 4},
#  {'t_id': 'Training_56543816.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 17.38265642569943,
#   'antelacion_de_compra': 68,
#   'id': 4},
#  {'t_id': 'Training_72647284.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.00448811448599,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'Training_78312130.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 17.998304794361616,
#   'antelacion_de_compra': 8,
#   'id': 4},
#  {'t_id': 'Training_85932660.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 14.503183329093467,
#   'antelacion_de_compra': 264,
#   'id': 4},
#  {'t_id': 'Training_91534280.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 17.515847630636983,
#   'antelacion_de_compra': 103,
#   'id': 4},
#  {'t_id': 'Training_94534277.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 22.707087140889186,
#   'antelacion_de_compra': 283,
#   'id': 4},
#  {'t_id': 'Training_1204614.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 18.05798035492054,
#   'antelacion_de_compra': 1,
#   'id': 4},
#  {'t_id': 'Training_15524948.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 7.22222716797234,
#   'antelacion_de_compra': 175,
#   'id': 4},
#  {'t_id': 'Training_57944429.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 11.754042034693118,
#   'antelacion_de_compra': 85,
#   'id': 4},
#  {'t_id': 'Training_68298637.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 28.661324837415766,
#   'antelacion_de_compra': 1,
#   'id': 4},
#  {'t_id': 'Training_72115626.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 10.67128793941382,
#   'antelacion_de_compra': 257,
#   'id': 4},
#  {'t_id': 'Training_86279124.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.202148315891,
#   'antelacion_de_compra': 69,
#   'id': 4},
#  {'t_id': 'Training_13319523.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 29.501347581981207,
#   'antelacion_de_compra': 307,
#   'id': 4},
#  {'t_id': 'Training_50683673.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 23.172129245706692,
#   'antelacion_de_compra': 358,
#   'id': 4},
#  {'t_id': 'Training_98409862.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.476414974589627,
#   'antelacion_de_compra': 198,
#   'id': 4},
#  {'t_id': 'PublicTest_93746530.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 24.071929934697447,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'PrivateTest_65546158.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.558657590857724,
#   'antelacion_de_compra': 211,
#   'id': 4},
#  {'t_id': 'PublicTest_23782142.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 22.220444744928237,
#   'antelacion_de_compra': 107,
#   'id': 4},
#  {'t_id': 'PublicTest_35686529.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 11.303996760742887,
#   'antelacion_de_compra': 87,
#   'id': 4},
#  {'t_id': 'PublicTest_88046230.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 8.783010707972633,
#   'antelacion_de_compra': 0,
#   'id': 4},
#  {'t_id': 'Training_10131352.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.059901873087654,
#   'antelacion_de_compra': 25,
#   'id': 5},
#  {'t_id': 'Training_15498699.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.918701764070143,
#   'antelacion_de_compra': 273,
#   'id': 5},
#  {'t_id': 'Training_16538275.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.05195604549761,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_27707888.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.066153694850758,
#   'antelacion_de_compra': 84,
#   'id': 5},
#  {'t_id': 'Training_33408401.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 19.18741087640996,
#   'antelacion_de_compra': 360,
#   'id': 5},
#  {'t_id': 'Training_35899521.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 21.66912339644148,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_46501880.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 18.89329348625639,
#   'antelacion_de_compra': 139,
#   'id': 5},
#  {'t_id': 'Training_49106080.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.943624994615224,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_53661557.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 20.532686162308327,
#   'antelacion_de_compra': 113,
#   'id': 5},
#  {'t_id': 'Training_81192903.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 14.08423339308465,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_84325046.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.28987776005606,
#   'antelacion_de_compra': 197,
#   'id': 5},
#  {'t_id': 'Training_90026754.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 11.366779789569241,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_91019189.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 26.764680752849582,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_96298080.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 9.63357462285771,
#   'antelacion_de_compra': 210,
#   'id': 5},
#  {'t_id': 'Training_98000381.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.352778117271207,
#   'antelacion_de_compra': 95,
#   'id': 5},
#  {'t_id': 'Training_18375779.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 11.016818989044733,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_25912105.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.576751907419407,
#   'antelacion_de_compra': 57,
#   'id': 5},
#  {'t_id': 'Training_33315056.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 9.088698950264485,
#   'antelacion_de_compra': 277,
#   'id': 5},
#  {'t_id': 'Training_5453423.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 24.816412097014783,
#   'antelacion_de_compra': 346,
#   'id': 5},
#  {'t_id': 'Training_77982832.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.762857521923866,
#   'antelacion_de_compra': 204,
#   'id': 5},
#  {'t_id': 'Training_12918469.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 7.666162603842954,
#   'antelacion_de_compra': 179,
#   'id': 5},
#  {'t_id': 'Training_14078248.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 12.23962877804394,
#   'antelacion_de_compra': 27,
#   'id': 5},
#  {'t_id': 'Training_36557536.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 17.031803951077105,
#   'antelacion_de_compra': 175,
#   'id': 5},
#  {'t_id': 'Training_36725406.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 15.23326981914089,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_41454428.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.66905786535031,
#   'antelacion_de_compra': 130,
#   'id': 5},
#  {'t_id': 'Training_69898122.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.962376486533167,
#   'antelacion_de_compra': 138,
#   'id': 5},
#  {'t_id': 'Training_9925349.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 12.231921333943669,
#   'antelacion_de_compra': 32,
#   'id': 5},
#  {'t_id': 'Training_13009130.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.701477734041056,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'Training_21050219.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 15.076840382588284,
#   'antelacion_de_compra': 320,
#   'id': 5},
#  {'t_id': 'Training_29858227.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 19.22203593808917,
#   'antelacion_de_compra': 63,
#   'id': 5},
#  {'t_id': 'Training_70265936.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 27.318667493140328,
#   'antelacion_de_compra': 331,
#   'id': 5},
#  {'t_id': 'Training_83848798.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 25.93922641095648,
#   'antelacion_de_compra': 28,
#   'id': 5},
#  {'t_id': 'Training_47173336.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.123657805350287,
#   'antelacion_de_compra': 195,
#   'id': 5},
#  {'t_id': 'Training_55847949.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.241437709523911,
#   'antelacion_de_compra': 287,
#   'id': 5},
#  {'t_id': 'Training_93101774.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.82509538204473,
#   'antelacion_de_compra': 0,
#   'id': 5},
#  {'t_id': 'PublicTest_43169549.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.862909437483822,
#   'antelacion_de_compra': 356,
#   'id': 5},
#  {'t_id': 'Training_10161559.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.722233590358808,
#   'antelacion_de_compra': 320,
#   'id': 6},
#  {'t_id': 'Training_25957924.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 24.428383768428247,
#   'antelacion_de_compra': 284,
#   'id': 6},
#  {'t_id': 'Training_25979060.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 8.997333211241834,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_30337890.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 16.4390434531949,
#   'antelacion_de_compra': 168,
#   'id': 6},
#  {'t_id': 'Training_44830316.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 12.88910251751598,
#   'antelacion_de_compra': 1,
#   'id': 6},
#  {'t_id': 'Training_51885310.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 16.08744841669684,
#   'antelacion_de_compra': 1,
#   'id': 6},
#  {'t_id': 'Training_60986125.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 10.461846044347402,
#   'antelacion_de_compra': 331,
#   'id': 6},
#  {'t_id': 'Training_62362932.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.30288342468166,
#   'antelacion_de_compra': 8,
#   'id': 6},
#  {'t_id': 'Training_6971336.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 7.428086749435883,
#   'antelacion_de_compra': 132,
#   'id': 6},
#  {'t_id': 'Training_22868376.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 10.479495935922566,
#   'antelacion_de_compra': 235,
#   'id': 6},
#  {'t_id': 'Training_26552601.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 13.345147783400297,
#   'antelacion_de_compra': 118,
#   'id': 6},
#  {'t_id': 'Training_28677017.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 10.941736487342489,
#   'antelacion_de_compra': 185,
#   'id': 6},
#  {'t_id': 'Training_42037605.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.81819649242384,
#   'antelacion_de_compra': 26,
#   'id': 6},
#  {'t_id': 'Training_70760624.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 23.297221010649515,
#   'antelacion_de_compra': 362,
#   'id': 6},
#  {'t_id': 'Training_87335410.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.836230829353248,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_12302906.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.702131196360458,
#   'antelacion_de_compra': 245,
#   'id': 6},
#  {'t_id': 'Training_36695637.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 24.480509641597507,
#   'antelacion_de_compra': 90,
#   'id': 6},
#  {'t_id': 'Training_5349872.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.219136814925434,
#   'antelacion_de_compra': 274,
#   'id': 6},
#  {'t_id': 'Training_6008930.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 14.994698664997422,
#   'antelacion_de_compra': 31,
#   'id': 6},
#  {'t_id': 'Training_77128306.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 11.345476175087756,
#   'antelacion_de_compra': 215,
#   'id': 6},
#  {'t_id': 'Training_77465577.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 21.750394347602743,
#   'antelacion_de_compra': 119,
#   'id': 6},
#  {'t_id': 'Training_91592034.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 16.24758378706041,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_3119601.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 12.43503653347933,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_25660075.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 12.634909485510644,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_2900169.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 17.783011183289346,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_7920978.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 25.27949040534991,
#   'antelacion_de_compra': 0,
#   'id': 6},
#  {'t_id': 'Training_96149283.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.891169644795461,
#   'antelacion_de_compra': 264,
#   'id': 6},
#  {'t_id': 'Training_17123874.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 8.543335544836864,
#   'antelacion_de_compra': 185,
#   'id': 6},
#  {'t_id': 'PublicTest_24489785.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 8.300610629446517,
#   'antelacion_de_compra': 1,
#   'id': 6},
#  {'t_id': 'PublicTest_85118178.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.54196531626764,
#   'antelacion_de_compra': 263,
#   'id': 6},
#  {'t_id': 'Training_1021836.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 20.501200189369893,
#   'antelacion_de_compra': 271,
#   'id': 7},
#  {'t_id': 'Training_15466417.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 21.495826433391752,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_19595003.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 14.509065496272274,
#   'antelacion_de_compra': 20,
#   'id': 7},
#  {'t_id': 'Training_54086407.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.88550517204413,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_73833007.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 22.22257384724011,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_81699068.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 22.830761635271816,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_9570645.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 31.928212671164545,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_98997562.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 14.84298192843498,
#   'antelacion_de_compra': 51,
#   'id': 7},
#  {'t_id': 'Training_13292144.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 23.129355695831297,
#   'antelacion_de_compra': 38,
#   'id': 7},
#  {'t_id': 'Training_15309290.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.135893254118326,
#   'antelacion_de_compra': 214,
#   'id': 7},
#  {'t_id': 'Training_29017000.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.135199309402893,
#   'antelacion_de_compra': 178,
#   'id': 7},
#  {'t_id': 'Training_74697679.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.221988480644303,
#   'antelacion_de_compra': 132,
#   'id': 7},
#  {'t_id': 'Training_82880182.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 10.996117314024266,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_18787866.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.60282328871874,
#   'antelacion_de_compra': 1,
#   'id': 7},
#  {'t_id': 'Training_22275808.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.05535125128901,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_28451921.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 8.484014032275969,
#   'antelacion_de_compra': 289,
#   'id': 7},
#  {'t_id': 'Training_28801334.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 24.517468656051157,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_31446845.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 13.51138974841231,
#   'antelacion_de_compra': 21,
#   'id': 7},
#  {'t_id': 'Training_32034953.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 18.005895570035552,
#   'antelacion_de_compra': 1,
#   'id': 7},
#  {'t_id': 'Training_46757857.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 19.615888875485652,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_5937598.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 16.94135704364433,
#   'antelacion_de_compra': 260,
#   'id': 7},
#  {'t_id': 'Training_64648532.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 16.44860456715834,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_11758836.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 16.651140468786128,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_12134104.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.435820158863962,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_12498684.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 15.811977431403928,
#   'antelacion_de_compra': 172,
#   'id': 7},
#  {'t_id': 'Training_21161378.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.147870752332565,
#   'antelacion_de_compra': 315,
#   'id': 7},
#  {'t_id': 'Training_58665762.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 15.207039838101444,
#   'antelacion_de_compra': 1,
#   'id': 7},
#  {'t_id': 'Training_16553115.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 5.312864349749988,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'Training_21297515.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.36250557591733,
#   'antelacion_de_compra': 0,
#   'id': 7},
#  {'t_id': 'PublicTest_82925571.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.9719475903552,
#   'antelacion_de_compra': 238,
#   'id': 7},
#  {'t_id': 'PublicTest_46731402.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 20.642276080505656,
#   'antelacion_de_compra': 130,
#   'id': 7},
#  {'t_id': 'PrivateTest_53534458.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 14.531026774156178,
#   'antelacion_de_compra': 232,
#   'id': 7},
#  {'t_id': 'PrivateTest_80960922.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 17.324913315154863,
#   'antelacion_de_compra': 87,
#   'id': 7},
#  {'t_id': 'Training_10269675.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 12.875701352903771,
#   'antelacion_de_compra': 0,
#   'id': 8},
#  {'t_id': 'Training_11576563.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 14.256584387133353,
#   'antelacion_de_compra': 5,
#   'id': 8},
#  {'t_id': 'Training_11990539.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 26.133002181480492,
#   'antelacion_de_compra': 0,
#   'id': 8},
#  {'t_id': 'Training_18766042.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.480532719461998,
#   'antelacion_de_compra': 183,
#   'id': 8},
#  {'t_id': 'Training_22662478.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 7.1264277463249,
#   'antelacion_de_compra': 285,
#   'id': 8},
#  {'t_id': 'Training_23854394.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 29.604284251643264,
#   'antelacion_de_compra': 182,
#   'id': 8},
#  {'t_id': 'Training_96672251.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.69903026699785,
#   'antelacion_de_compra': 0,
#   'id': 8},
#  {'t_id': 'Training_23759223.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.825242913272216,
#   'antelacion_de_compra': 0,
#   'id': 8},
#  {'t_id': 'Training_3573297.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.74365103271684,
#   'antelacion_de_compra': 97,
#   'id': 8},
#  {'t_id': 'Training_58353816.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.25619821698925,
#   'antelacion_de_compra': 210,
#   'id': 8},
#  {'t_id': 'Training_6044803.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 18.072670172585223,
#   'antelacion_de_compra': 22,
#   'id': 8},
#  {'t_id': 'Training_80735344.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 26.350199082855468,
#   'antelacion_de_compra': 1,
#   'id': 8},
#  {'t_id': 'Training_85976655.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 12.809188266641728,
#   'antelacion_de_compra': 223,
#   'id': 8},
#  {'t_id': 'Training_90019797.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 16.770917881502175,
#   'antelacion_de_compra': 137,
#   'id': 8},
#  {'t_id': 'Training_22805885.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.39222296260408,
#   'antelacion_de_compra': 116,
#   'id': 8},
#  {'t_id': 'Training_48006396.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.685066763279183,
#   'antelacion_de_compra': 122,
#   'id': 8},
#  {'t_id': 'Training_93177841.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.825997140630177,
#   'antelacion_de_compra': 201,
#   'id': 8},
#  {'t_id': 'Training_13658077.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.80797230705154,
#   'antelacion_de_compra': 91,
#   'id': 8},
#  {'t_id': 'Training_15858912.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.22577653587546,
#   'antelacion_de_compra': 262,
#   'id': 8},
#  {'t_id': 'Training_27035614.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.971514662172737,
#   'antelacion_de_compra': 36,
#   'id': 8},
#  {'t_id': 'Training_24360152.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 22.912299279720035,
#   'antelacion_de_compra': 317,
#   'id': 8},
#  {'t_id': 'Training_39551863.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.757707027472605,
#   'antelacion_de_compra': 137,
#   'id': 8},
#  {'t_id': 'Training_64798486.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.683758064721044,
#   'antelacion_de_compra': 2,
#   'id': 8},
#  {'t_id': 'PublicTest_82552414.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 21.743930682561626,
#   'antelacion_de_compra': 27,
#   'id': 8},
#  {'t_id': 'PublicTest_22477942.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 22.685861179378527,
#   'antelacion_de_compra': 249,
#   'id': 8},
#  {'t_id': 'PublicTest_32658045.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 5.537647758463127,
#   'antelacion_de_compra': 146,
#   'id': 8},
#  {'t_id': 'PrivateTest_49758740.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 10.406459768591564,
#   'antelacion_de_compra': 181,
#   'id': 8},
#  {'t_id': 'PublicTest_90946837.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 12.05840558806242,
#   'antelacion_de_compra': 298,
#   'id': 8},
#  {'t_id': 'PrivateTest_44387244.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 21.52034468383857,
#   'antelacion_de_compra': 259,
#   'id': 8},
#  {'t_id': 'PrivateTest_98453427.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 27.069129336486796,
#   'antelacion_de_compra': 310,
#   'id': 8},
#  {'t_id': 'Training_10278738.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.67823675192296,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_14054767.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 13.851856930211916,
#   'antelacion_de_compra': 187,
#   'id': 9},
#  {'t_id': 'Training_14621559.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 10.407170475998328,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_1500617.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.065846421750486,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_22407840.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.115979936248877,
#   'antelacion_de_compra': 267,
#   'id': 9},
#  {'t_id': 'Training_25941890.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 19.982289026369735,
#   'antelacion_de_compra': 320,
#   'id': 9},
#  {'t_id': 'Training_3480868.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.567439815813138,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_35227874.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 23.883367791679355,
#   'antelacion_de_compra': 329,
#   'id': 9},
#  {'t_id': 'Training_38557671.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 10.273553291811009,
#   'antelacion_de_compra': 65,
#   'id': 9},
#  {'t_id': 'Training_43485342.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 17.227492106402742,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_44019301.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 24.157871919003423,
#   'antelacion_de_compra': 102,
#   'id': 9},
#  {'t_id': 'Training_59953801.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 11.171099698292913,
#   'antelacion_de_compra': 7,
#   'id': 9},
#  {'t_id': 'Training_63330481.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 24.528526428343792,
#   'antelacion_de_compra': 132,
#   'id': 9},
#  {'t_id': 'Training_79786106.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 7.677011190929948,
#   'antelacion_de_compra': 340,
#   'id': 9},
#  {'t_id': 'Training_81438547.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 10.642964508003285,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_27972185.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 22.60820593109971,
#   'antelacion_de_compra': 203,
#   'id': 9},
#  {'t_id': 'Training_3082951.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 26.514100144149083,
#   'antelacion_de_compra': 330,
#   'id': 9},
#  {'t_id': 'Training_30962418.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 10.63349004650063,
#   'antelacion_de_compra': 291,
#   'id': 9},
#  {'t_id': 'Training_40636222.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 7.492633557041389,
#   'antelacion_de_compra': 229,
#   'id': 9},
#  {'t_id': 'Training_49607398.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 12.297003958939554,
#   'antelacion_de_compra': 338,
#   'id': 9},
#  {'t_id': 'Training_55213475.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 10.708006542247976,
#   'antelacion_de_compra': 169,
#   'id': 9},
#  {'t_id': 'Training_80171012.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.82829275793642,
#   'antelacion_de_compra': 162,
#   'id': 9},
#  {'t_id': 'Training_9433235.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 13.876949497535655,
#   'antelacion_de_compra': 2,
#   'id': 9},
#  {'t_id': 'Training_11164844.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 15.27234605359715,
#   'antelacion_de_compra': 1,
#   'id': 9},
#  {'t_id': 'Training_14669195.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.010997936338555,
#   'antelacion_de_compra': 153,
#   'id': 9},
#  {'t_id': 'Training_21590511.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.263349577756884,
#   'antelacion_de_compra': 345,
#   'id': 9},
#  {'t_id': 'Training_47828209.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.609665530649313,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_48142094.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.629008467828161,
#   'antelacion_de_compra': 63,
#   'id': 9},
#  {'t_id': 'Training_48209345.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 12.94021831100518,
#   'antelacion_de_compra': 188,
#   'id': 9},
#  {'t_id': 'Training_77976444.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.462394346791722,
#   'antelacion_de_compra': 258,
#   'id': 9},
#  {'t_id': 'Training_96866302.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 15.238060133665636,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'Training_53161413.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 21.214933408986607,
#   'antelacion_de_compra': 1,
#   'id': 9},
#  {'t_id': 'PublicTest_90129237.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 26.42815825942373,
#   'antelacion_de_compra': 286,
#   'id': 9},
#  {'t_id': 'PublicTest_32023453.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 16.776606228914805,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'PrivateTest_52900614.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 15.436977693837527,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'PublicTest_48364789.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 24.452233150386167,
#   'antelacion_de_compra': 107,
#   'id': 9},
#  {'t_id': 'PrivateTest_29873933.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.071432767082644,
#   'antelacion_de_compra': 295,
#   'id': 9},
#  {'t_id': 'PublicTest_69843457.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 11.054187445544013,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'PrivateTest_71175068.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.048416628605384,
#   'antelacion_de_compra': 0,
#   'id': 9},
#  {'t_id': 'PublicTest_92242142.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 23.968088723856127,
#   'antelacion_de_compra': 191,
#   'id': 9},
#  {'t_id': 'Training_10290703.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 20.40562504073693,
#   'antelacion_de_compra': 7,
#   'id': 10},
#  {'t_id': 'Training_19103814.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.693181710890983,
#   'antelacion_de_compra': 159,
#   'id': 10},
#  {'t_id': 'Training_27785233.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 17.44355358896667,
#   'antelacion_de_compra': 133,
#   'id': 10},
#  {'t_id': 'Training_36795431.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 21.37782452396304,
#   'antelacion_de_compra': 329,
#   'id': 10},
#  {'t_id': 'Training_43438109.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.874917584541013,
#   'antelacion_de_compra': 52,
#   'id': 10},
#  {'t_id': 'Training_56677459.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 22.206887063632475,
#   'antelacion_de_compra': 299,
#   'id': 10},
#  {'t_id': 'Training_64388896.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.440586427621753,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_64992219.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.33373883974548,
#   'antelacion_de_compra': 328,
#   'id': 10},
#  {'t_id': 'Training_74292043.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 21.667769061223904,
#   'antelacion_de_compra': 2,
#   'id': 10},
#  {'t_id': 'Training_90018042.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 29.003983652300633,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_17997300.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.29748625750811,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_29782340.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 27.884988924234964,
#   'antelacion_de_compra': 75,
#   'id': 10},
#  {'t_id': 'Training_40907405.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 14.19599310503816,
#   'antelacion_de_compra': 194,
#   'id': 10},
#  {'t_id': 'Training_42312801.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.488887971313453,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_55945756.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 20.69982791243824,
#   'antelacion_de_compra': 2,
#   'id': 10},
#  {'t_id': 'Training_74264970.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 13.674493005265944,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_94131837.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.52253623457098,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_98459017.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.52784114075623,
#   'antelacion_de_compra': 349,
#   'id': 10},
#  {'t_id': 'Training_12375272.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.61186276933204,
#   'antelacion_de_compra': 157,
#   'id': 10},
#  {'t_id': 'Training_13990170.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 17.06775690633159,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_46120187.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 21.805738731861247,
#   'antelacion_de_compra': 83,
#   'id': 10},
#  {'t_id': 'Training_52023624.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.30068435723347,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_90487023.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 19.48886996851712,
#   'antelacion_de_compra': 362,
#   'id': 10},
#  {'t_id': 'Training_99605415.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 10.104541959086728,
#   'antelacion_de_compra': 242,
#   'id': 10},
#  {'t_id': 'Training_22002519.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 25.413169634444138,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_27185781.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.09743391654816,
#   'antelacion_de_compra': 261,
#   'id': 10},
#  {'t_id': 'Training_49115160.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 17.836497675163024,
#   'antelacion_de_compra': 266,
#   'id': 10},
#  {'t_id': 'Training_75065805.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 10.836745353562549,
#   'antelacion_de_compra': 2,
#   'id': 10},
#  {'t_id': 'Training_83332359.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.980453097239604,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_24953459.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.34859664993509,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_40135555.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.117504840645147,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'Training_58533722.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 21.423869255179817,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'PublicTest_49302808.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 11.621074826915766,
#   'antelacion_de_compra': 0,
#   'id': 10},
#  {'t_id': 'PublicTest_91481838.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 22.684166051235756,
#   'antelacion_de_compra': 2,
#   'id': 10},
#  {'t_id': 'PrivateTest_21475770.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.433467698716793,
#   'antelacion_de_compra': 293,
#   'id': 10},
#  {'t_id': 'PublicTest_10709121.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 22.973699090371795,
#   'antelacion_de_compra': 243,
#   'id': 10},
#  {'t_id': 'Training_10295477.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.436528375831672,
#   'antelacion_de_compra': 149,
#   'id': 11},
#  {'t_id': 'Training_14417147.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.766109969980988,
#   'antelacion_de_compra': 146,
#   'id': 11},
#  {'t_id': 'Training_15311033.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 21.87784183198138,
#   'antelacion_de_compra': 1,
#   'id': 11},
#  {'t_id': 'Training_30549878.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 18.899460653292653,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_37967715.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 25.451315205488466,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_43678585.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 15.67506169329664,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_52020878.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 6.608215336820265,
#   'antelacion_de_compra': 1,
#   'id': 11},
#  {'t_id': 'Training_6506913.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.25210069817025,
#   'antelacion_de_compra': 4,
#   'id': 11},
#  {'t_id': 'Training_6815405.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.834361690825729,
#   'antelacion_de_compra': 207,
#   'id': 11},
#  {'t_id': 'Training_73990468.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.144436155305058,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_87636016.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 13.896599963239186,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_87875595.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.6501100998785,
#   'antelacion_de_compra': 348,
#   'id': 11},
#  {'t_id': 'Training_96859053.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 22.98161404721062,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_18811387.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.80647227371501,
#   'antelacion_de_compra': 95,
#   'id': 11},
#  {'t_id': 'Training_30944761.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.471799244342378,
#   'antelacion_de_compra': 286,
#   'id': 11},
#  {'t_id': 'Training_56563285.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 7.1733785645906885,
#   'antelacion_de_compra': 213,
#   'id': 11},
#  {'t_id': 'Training_97922976.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 19.38794152823399,
#   'antelacion_de_compra': 1,
#   'id': 11},
#  {'t_id': 'Training_98930348.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.188699816439808,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_12630394.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 11.887907355092695,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_51683025.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.292548770337266,
#   'antelacion_de_compra': 229,
#   'id': 11},
#  {'t_id': 'Training_55338326.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.10037924418645,
#   'antelacion_de_compra': 242,
#   'id': 11},
#  {'t_id': 'Training_57684401.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 6.615341682682029,
#   'antelacion_de_compra': 179,
#   'id': 11},
#  {'t_id': 'Training_64809371.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 27.646049037899807,
#   'antelacion_de_compra': 13,
#   'id': 11},
#  {'t_id': 'Training_66460314.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.918872836007731,
#   'antelacion_de_compra': 166,
#   'id': 11},
#  {'t_id': 'Training_90810939.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 17.786698309329086,
#   'antelacion_de_compra': 303,
#   'id': 11},
#  {'t_id': 'Training_92216142.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.025415875360093,
#   'antelacion_de_compra': 15,
#   'id': 11},
#  {'t_id': 'Training_95890455.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.56409977197023,
#   'antelacion_de_compra': 321,
#   'id': 11},
#  {'t_id': 'Training_97834497.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.356257935960436,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'Training_18417999.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.05862930905365,
#   'antelacion_de_compra': 313,
#   'id': 11},
#  {'t_id': 'Training_99019653.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.04159671243886,
#   'antelacion_de_compra': 8,
#   'id': 11},
#  {'t_id': 'Training_28852731.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.76187318047901,
#   'antelacion_de_compra': 43,
#   'id': 11},
#  {'t_id': 'Training_15146606.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 23.01228098426805,
#   'antelacion_de_compra': 0,
#   'id': 11},
#  {'t_id': 'PrivateTest_56425128.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.202081171234816,
#   'antelacion_de_compra': 161,
#   'id': 11},
#  {'t_id': 'PublicTest_25271883.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 10.826121249576245,
#   'antelacion_de_compra': 14,
#   'id': 11},
#  {'t_id': 'PublicTest_66548039.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.152449602082765,
#   'antelacion_de_compra': 97,
#   'id': 11},
#  {'t_id': 'PublicTest_24738517.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 21.488883522585347,
#   'antelacion_de_compra': 4,
#   'id': 11},
#  {'t_id': 'Training_10315441.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 29.028055064510678,
#   'antelacion_de_compra': 146,
#   'id': 12},
#  {'t_id': 'Training_14525872.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.706480956184361,
#   'antelacion_de_compra': 353,
#   'id': 12},
#  {'t_id': 'Training_31734020.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.80313588119699,
#   'antelacion_de_compra': 59,
#   'id': 12},
#  {'t_id': 'Training_32392069.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.515889667464606,
#   'antelacion_de_compra': 72,
#   'id': 12},
#  {'t_id': 'Training_3598867.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 12.943116166829673,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_38455066.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 20.22287033810813,
#   'antelacion_de_compra': 30,
#   'id': 12},
#  {'t_id': 'Training_40376269.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 19.14666586975526,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_46004786.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 19.896476918701403,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_51021087.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.837378283085359,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_56803130.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 22.83664802532644,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_7326263.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 17.14142162905347,
#   'antelacion_de_compra': 205,
#   'id': 12},
#  {'t_id': 'Training_8913468.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.324649470790316,
#   'antelacion_de_compra': 304,
#   'id': 12},
#  {'t_id': 'Training_94952701.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.954599031703236,
#   'antelacion_de_compra': 98,
#   'id': 12},
#  {'t_id': 'Training_95101318.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 22.142362377314946,
#   'antelacion_de_compra': 32,
#   'id': 12},
#  {'t_id': 'Training_16906911.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 18.228745702514104,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_20052779.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 25.41867353651155,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_20431293.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 10.823642588713618,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_6000078.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 17.409807628936516,
#   'antelacion_de_compra': 64,
#   'id': 12},
#  {'t_id': 'Training_75208855.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 24.992005766951156,
#   'antelacion_de_compra': 0,
#   'id': 12},
#  {'t_id': 'Training_977035.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 24.434176024118138,
#   'antelacion_de_compra': 0,
# ...
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 12.762811300072674,
#   'antelacion_de_compra': 120,
#   'id': 28},
#  {'t_id': 'Training_3599060.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 20.45582213833452,
#   'antelacion_de_compra': 101,
#   'id': 28},
#  {'t_id': 'Training_47757511.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 20.679306028326852,
#   'antelacion_de_compra': 0,
#   'id': 28},
#  {'t_id': 'Training_77947880.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.13368482242192,
#   'antelacion_de_compra': 167,
#   'id': 28},
#  {'t_id': 'Training_98998460.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 21.079398653343702,
#   'antelacion_de_compra': 145,
#   'id': 28},
#  {'t_id': 'Training_25837475.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 17.268702363940275,
#   'antelacion_de_compra': 2,
#   'id': 28},
#  {'t_id': 'Training_74013604.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 12.201655382166177,
#   'antelacion_de_compra': 146,
#   'id': 28},
#  {'t_id': 'Training_87159647.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 25.83095390529519,
#   'antelacion_de_compra': 175,
#   'id': 28},
#  {'t_id': 'Training_95612623.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 18.686530443541297,
#   'antelacion_de_compra': 334,
#   'id': 28},
#  {'t_id': 'Training_81607578.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 6.785904106235799,
#   'antelacion_de_compra': 339,
#   'id': 28},
#  {'t_id': 'Training_93625113.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.593398334736944,
#   'antelacion_de_compra': 0,
#   'id': 28},
#  {'t_id': 'PrivateTest_80228315.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 12.135389917609988,
#   'antelacion_de_compra': 360,
#   'id': 28},
#  {'t_id': 'PublicTest_85457087.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 24.496589068268776,
#   'antelacion_de_compra': 1,
#   'id': 28},
#  {'t_id': 'PublicTest_28215339.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.93038687085327,
#   'antelacion_de_compra': 192,
#   'id': 28},
#  {'t_id': 'PublicTest_15712657.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 23.528052544000925,
#   'antelacion_de_compra': 19,
#   'id': 28},
#  {'t_id': 'Training_10899258.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.15095944976282,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_15693625.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.379240300864222,
#   'antelacion_de_compra': 339,
#   'id': 29},
#  {'t_id': 'Training_1854333.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 12.29601567139694,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_19756127.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 23.76027724211907,
#   'antelacion_de_compra': 1,
#   'id': 29},
#  {'t_id': 'Training_20317679.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 18.11156595491701,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_27913729.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 9.829480427599776,
#   'antelacion_de_compra': 185,
#   'id': 29},
#  {'t_id': 'Training_28677280.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.56365205514041,
#   'antelacion_de_compra': 66,
#   'id': 29},
#  {'t_id': 'Training_28766758.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 20.141362886751043,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_62131804.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.25281938582215,
#   'antelacion_de_compra': 81,
#   'id': 29},
#  {'t_id': 'Training_70542188.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 23.745480648480363,
#   'antelacion_de_compra': 95,
#   'id': 29},
#  {'t_id': 'Training_87491436.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 9.108033010981634,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_25395654.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.621347033145454,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_32346910.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 15.189155377401255,
#   'antelacion_de_compra': 182,
#   'id': 29},
#  {'t_id': 'Training_11277443.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 18.41486550685772,
#   'antelacion_de_compra': 321,
#   'id': 29},
#  {'t_id': 'Training_13043044.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 18.670924631287296,
#   'antelacion_de_compra': 315,
#   'id': 29},
#  {'t_id': 'Training_24953497.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 15.413612183803616,
#   'antelacion_de_compra': 210,
#   'id': 29},
#  {'t_id': 'Training_37781713.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 17.413948001558815,
#   'antelacion_de_compra': 2,
#   'id': 29},
#  {'t_id': 'Training_38715647.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 25.58739089709386,
#   'antelacion_de_compra': 243,
#   'id': 29},
#  {'t_id': 'Training_57103994.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 16.552342596046746,
#   'antelacion_de_compra': 330,
#   'id': 29},
#  {'t_id': 'Training_58594964.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.602771571828452,
#   'antelacion_de_compra': 110,
#   'id': 29},
#  {'t_id': 'Training_80424540.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 19.94457734320326,
#   'antelacion_de_compra': 349,
#   'id': 29},
#  {'t_id': 'Training_83103387.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 18.785571002170325,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_23638725.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 14.882801415831883,
#   'antelacion_de_compra': 40,
#   'id': 29},
#  {'t_id': 'Training_81500597.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 19.37314174022761,
#   'antelacion_de_compra': 165,
#   'id': 29},
#  {'t_id': 'Training_81556708.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.20461716821654,
#   'antelacion_de_compra': 86,
#   'id': 29},
#  {'t_id': 'Training_8245285.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.77203450883863,
#   'antelacion_de_compra': 2,
#   'id': 29},
#  {'t_id': 'Training_17446637.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 13.655406194814264,
#   'antelacion_de_compra': 178,
#   'id': 29},
#  {'t_id': 'Training_32584947.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 10.889547543527545,
#   'antelacion_de_compra': 35,
#   'id': 29},
#  {'t_id': 'Training_46651631.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.620871331285237,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_66538546.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.455236972774173,
#   'antelacion_de_compra': 356,
#   'id': 29},
#  {'t_id': 'Training_81658867.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 15.973512661503579,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'Training_65806289.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 11.2184811950205,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'PrivateTest_14182117.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 26.443521559570716,
#   'antelacion_de_compra': 0,
#   'id': 29},
#  {'t_id': 'PrivateTest_85904615.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.986671456232678,
#   'antelacion_de_compra': 58,
#   'id': 29},
#  {'t_id': 'PrivateTest_3534072.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 18.934783569507672,
#   'antelacion_de_compra': 340,
#   'id': 29},
#  {'t_id': 'PublicTest_47899862.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.566396084916551,
#   'antelacion_de_compra': 56,
#   'id': 29},
#  {'t_id': 'Training_10922970.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 10.926006384930172,
#   'antelacion_de_compra': 359,
#   'id': 30},
#  {'t_id': 'Training_21576940.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 22.696548053884825,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_37599849.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 21.075291726760476,
#   'antelacion_de_compra': 1,
#   'id': 30},
#  {'t_id': 'Training_62364164.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 6.000252951499178,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_6325945.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.556737441337987,
#   'antelacion_de_compra': 224,
#   'id': 30},
#  {'t_id': 'Training_65912489.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 16.68110726469586,
#   'antelacion_de_compra': 238,
#   'id': 30},
#  {'t_id': 'Training_8240676.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 20.83352481392739,
#   'antelacion_de_compra': 202,
#   'id': 30},
#  {'t_id': 'Training_98328519.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 15.537838510569076,
#   'antelacion_de_compra': 111,
#   'id': 30},
#  {'t_id': 'Training_30471858.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 11.980633369770638,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_47450780.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 14.66948184334025,
#   'antelacion_de_compra': 2,
#   'id': 30},
#  {'t_id': 'Training_49726190.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 18.9593091252601,
#   'antelacion_de_compra': 261,
#   'id': 30},
#  {'t_id': 'Training_52199927.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.926053656976126,
#   'antelacion_de_compra': 308,
#   'id': 30},
#  {'t_id': 'Training_6732726.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 9.145010566297081,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_93927977.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.729361464423935,
#   'antelacion_de_compra': 5,
#   'id': 30},
#  {'t_id': 'Training_44322637.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 23.22463227600351,
#   'antelacion_de_compra': 32,
#   'id': 30},
#  {'t_id': 'Training_72951258.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 20.08807361175147,
#   'antelacion_de_compra': 203,
#   'id': 30},
#  {'t_id': 'Training_79192940.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.513235107605528,
#   'antelacion_de_compra': 31,
#   'id': 30},
#  {'t_id': 'Training_98110234.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.253443849006512,
#   'antelacion_de_compra': 55,
#   'id': 30},
#  {'t_id': 'Training_58865055.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 11.463106739676594,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_95005201.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.020549243598737,
#   'antelacion_de_compra': 290,
#   'id': 30},
#  {'t_id': 'Training_11077810.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 22.3636172521135,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_16166177.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 20.90252355400681,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_4038958.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 8.804377193084875,
#   'antelacion_de_compra': 289,
#   'id': 30},
#  {'t_id': 'Training_54298472.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 13.56591505762969,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_73884877.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 18.11116905273255,
#   'antelacion_de_compra': 0,
#   'id': 30},
#  {'t_id': 'Training_74435111.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.115400296102274,
#   'antelacion_de_compra': 356,
#   'id': 30},
#  {'t_id': 'Training_93173045.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 9.684185569801532,
#   'antelacion_de_compra': 111,
#   'id': 30},
#  {'t_id': 'Training_38768082.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 11.572051194950362,
#   'antelacion_de_compra': 248,
#   'id': 30},
#  {'t_id': 'PrivateTest_38456003.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 6.6524168889192286,
#   'antelacion_de_compra': 2,
#   'id': 30},
#  {'t_id': 'PublicTest_96161493.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 11.46662516585296,
#   'antelacion_de_compra': 2,
#   'id': 30},
#  {'t_id': 'PrivateTest_20475755.jpg',
#   'tipo_entrada': 'Entrada Familiar',
#   'coste': 20.4974834540053,
#   'antelacion_de_compra': 161,
#   'id': 30},
#  {'t_id': 'PrivateTest_62067922.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 19.517855006046712,
#   'antelacion_de_compra': 38,
#   'id': 30},
#  {'t_id': 'PrivateTest_61855708.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 20.920452590688,
#   'antelacion_de_compra': 81,
#   'id': 30},
#  {'t_id': 'Training_10967257.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 16.452489955865495,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_22607108.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 25.900459651945923,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_34758750.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 19.597981239070663,
#   'antelacion_de_compra': 1,
#   'id': 31},
#  {'t_id': 'Training_36894301.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 17.425464617088572,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_49277120.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 15.989116801733152,
#   'antelacion_de_compra': 281,
#   'id': 31},
#  {'t_id': 'Training_51002390.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 24.4915582337648,
#   'antelacion_de_compra': 100,
#   'id': 31},
#  {'t_id': 'Training_52524029.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 16.508030395281597,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_59755019.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 12.389434394766464,
#   'antelacion_de_compra': 157,
#   'id': 31},
#  {'t_id': 'Training_88442165.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 15.23123006915209,
#   'antelacion_de_compra': 107,
#   'id': 31},
#  {'t_id': 'Training_15892719.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 15.572503998636979,
#   'antelacion_de_compra': 1,
#   'id': 31},
#  {'t_id': 'Training_99984859.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 18.338205309253055,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_12564330.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 13.235269152703761,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_23975523.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 18.354872719885538,
#   'antelacion_de_compra': 351,
#   'id': 31},
#  {'t_id': 'Training_4382698.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 19.682796088027956,
#   'antelacion_de_compra': 8,
#   'id': 31},
#  {'t_id': 'Training_67295179.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 17.455130856389523,
#   'antelacion_de_compra': 364,
#   'id': 31},
#  {'t_id': 'Training_68130119.jpg',
#   'tipo_entrada': 'Pase Rápido',
#   'coste': 32.00954363142313,
#   'antelacion_de_compra': 149,
#   'id': 31},
#  {'t_id': 'Training_75661231.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 13.425031038662137,
#   'antelacion_de_compra': 234,
#   'id': 31},
#  {'t_id': 'Training_81270624.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 25.72218236271747,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_8842240.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 23.184993808965732,
#   'antelacion_de_compra': 261,
#   'id': 31},
#  {'t_id': 'Training_89354604.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 26.46235329978968,
#   'antelacion_de_compra': 314,
#   'id': 31},
#  {'t_id': 'Training_89975158.jpg',
#   'tipo_entrada': 'Entrada Infantil',
#   'coste': 10.380190860225786,
#   'antelacion_de_compra': 78,
#   'id': 31},
#  {'t_id': 'Training_90815186.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 19.92471793767983,
#   'antelacion_de_compra': 0,
#   'id': 31},
#  {'t_id': 'Training_99971684.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 21.72554481093603,
#   'antelacion_de_compra': 74,
#   'id': 31},
#  {'t_id': 'Training_41803027.jpg',
#   'tipo_entrada': 'Pase Anual',
#   'coste': 21.890855212874854,
#   'antelacion_de_compra': 297,
#   'id': 31},
#  {'t_id': 'Training_69706052.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 21.905390235300416,
#   'antelacion_de_compra': 339,
#   'id': 31},
#  {'t_id': 'Training_2913.jpg',
#   'tipo_entrada': 'Entrada Individual',
#   'coste': 17.941516944547097,
#   'antelacion_de_compra': 14,
#   'id': 31},
#  {'t_id': 'Training_90025070.jpg',
#   'tipo_entrada': 'Paquete VIP',
#   'coste': 14.851065896443208,
#   'antelacion_de_compra': 28,
#   'id': 31},
#  ...]

# %%
#Lo convertimos en df
df = pd.DataFrame(datos)
df.head()
# Out:
#                     t_id      tipo_entrada      coste  antelacion_de_compra  \
# 0  Training_10118481.jpg        Pase Anual  14.003708                     0
# 1  Training_15361067.jpg  Entrada Familiar  20.900902                     2
# 2  Training_16232328.jpg  Entrada Infantil  12.638039                   218
# 3  Training_27705571.jpg       Paquete VIP  18.491775                    39
# 4  Training_63766171.jpg  Entrada Familiar  18.233458                   135
#
#    id
# 0   3
# 1   3
# 2   3
# 3   3
# 4   3

# %% [markdown]
# ## 2 - Limpieza del df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   t_id                  35887 non-null  object
#  1   tipo_entrada          35887 non-null  object
#  2   coste                 35887 non-null  float64
#  3   antelacion_de_compra  35887 non-null  int64
#  4   id                    35887 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (35887, 5)

# %%
#Renombramos la columna para que coincida con los datos.
df.rename(columns = {'id':'id_visitante'}, inplace=True)
df.head()
# Out:
#                     t_id      tipo_entrada      coste  antelacion_de_compra  \
# 0  Training_10118481.jpg        Pase Anual  14.003708                     0
# 1  Training_15361067.jpg  Entrada Familiar  20.900902                     2
# 2  Training_16232328.jpg  Entrada Infantil  12.638039                   218
# 3  Training_27705571.jpg       Paquete VIP  18.491775                    39
# 4  Training_63766171.jpg  Entrada Familiar  18.233458                   135
#
#    id_visitante
# 0             3
# 1             3
# 2             3
# 3             3
# 4             3

# %%
#Confirmamos que no hay nulos.
df.isnull().sum()
# Out:
# t_id                    0
# tipo_entrada            0
# coste                   0
# antelacion_de_compra    0
# id_visitante            0
# dtype: int64

# %% [markdown]
# ## 3 - Descarga del documento limpio

# %%
#Me descargo el csv con la columna de las fechas
df.to_csv("id_visitante_ticket_limpio.csv",index=False)
