# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
# Rutas completas
TRAIN_PATH = r"C:\Users\USUARIO\Desktop\ModelosML\archivos\train"
TEST_PATH = r"C:\Users\USUARIO\Desktop\ModelosML\archivos\test"
BASE_PATH = r"C:\Users\USUARIO\Desktop\ModelosML\archivos\archive"

# %%
# Definir las dimensiones de las imágenes (48x48, 1 canal para escala de grises)
IMG_HEIGHT = 48
IMG_WIDTH = 48
BATCH_SIZE = 32
CHANNELS = 1  # Escala de grises

# %%
# Definir las clases (emociones en inglés)
CLASSES = ['surprise', 'happy', 'neutral', 'angry', 'fear', 'sad', 'disgust']

# %%
# Crear generadores de datos con aumentación (mismo nivel que el modelo original)
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

# %%
# Generador para el conjunto de entrenamiento
train_generator = datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASSES,
    subset='training',
    shuffle=True
)
# Out:
# Found 22968 images belonging to 7 classes.

# %%
# Generador para el conjunto de validación
validation_generator = datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASSES,
    subset='validation',
    shuffle=False
)
# Out:
# Found 5741 images belonging to 7 classes.

# %%
# Generador para el conjunto de prueba (sin aumentación)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASSES,
    shuffle=False
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Obtener el número de clases y el mapeo de clases
num_classes = len(CLASSES)
class_indices = train_generator.class_indices
print("Número de clases:", num_classes)
print("Clases:", class_indices)
# Out:
# Número de clases: 7
# Clases: {'surprise': 0, 'happy': 1, 'neutral': 2, 'angry': 3, 'fear': 4, 'sad': 5, 'disgust': 6}

# %%
# Definir pesos de clase manualmente
class_weights_dict = {
    class_indices['surprise']: 2.3,  # 3171 imágenes
    class_indices['happy']: 1.0,    # 7215 imágenes
    class_indices['neutral']: 1.5,  # 4930 imágenes
    class_indices['angry']: 1.8,    # 3995 imágenes
    class_indices['fear']: 1.8,     # 4095 imágenes
    class_indices['sad']: 1.5,      # 4953 imágenes
    class_indices['disgust']: 10.0  # 436 imágenes
}
print("Pesos de clase:", class_weights_dict)
# Out:
# Pesos de clase: {0: 2.3, 1: 1.0, 2: 1.5, 3: 1.8, 4: 1.8, 5: 1.5, 6: 10.0}

# %%
# Construir la arquitectura Mini-Xception original
def mini_xception(input_shape, num_classes):
    input_layer = Input(shape=input_shape)

    # Primer bloque
    x = Conv2D(8, (3, 3), padding='same', strides=(1, 1), use_bias=False)(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(8, (3, 3), padding='same', strides=(1, 1), use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Primer módulo residual
    residual = Conv2D(16, (1, 1), strides=(1, 1), padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)
    residual = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(residual)

    x = SeparableConv2D(16, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(16, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Add()([x, residual])

    # Segundo módulo residual
    residual = Conv2D(32, (1, 1), strides=(1, 1), padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)
    residual = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(residual)

    x = SeparableConv2D(32, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(32, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Add()([x, residual])

    # Tercer módulo residual
    residual = Conv2D(64, (1, 1), strides=(1, 1), padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)
    residual = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(residual)

    x = SeparableConv2D(64, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(64, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Add()([x, residual])

    # Capa final
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
# Crear el modelo Mini-Xception
model = mini_xception(input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS), num_classes=num_classes)

# %%
# Compilar el modelo con Categorical Crossentropy
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Resumen del modelo
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 8)    72          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 8)   32          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 48, 48, 8)    0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 48, 48, 8)    576         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 48, 8)   32          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 48, 48, 8)    0           ['batch_normalization_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 48, 48, 16)  200         ['activation_1[0][0]']
#  v2D)
#
#  batch_normalization_3 (BatchNo  (None, 48, 48, 16)  64          ['separable_conv2d[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 48, 48, 16)   0           ['batch_normalization_3[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 48, 48, 16)  400         ['activation_2[0][0]']
#  onv2D)
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 16)   128         ['activation_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 48, 16)  64          ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 48, 48, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 16)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 16)   0           ['batch_normalization_2[0][0]']
#
#  add (Add)                      (None, 24, 24, 16)   0           ['max_pooling2d_1[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 24, 24, 32)  656         ['add[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 24, 24, 32)  128         ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 24, 24, 32)   0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 24, 24, 32)  1312        ['activation_3[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 32)   512         ['add[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 24, 24, 32)  128         ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 24, 24, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 32)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 32)  0           ['batch_normalization_5[0][0]']
#
#  add_1 (Add)                    (None, 12, 12, 32)   0           ['max_pooling2d_3[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 12, 12, 64)  2336        ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 12, 12, 64)  256         ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 12, 12, 64)   0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 12, 12, 64)  4672        ['activation_4[0][0]']
#  onv2D)
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 64)   2048        ['add_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 12, 64)  256         ['separable_conv2d_5[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 12, 12, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 64)    0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 64)    0           ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (None, 6, 6, 64)     0           ['max_pooling2d_5[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['add_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          8320        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 7)            903         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 23,543
# Trainable params: 22,839
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
# Callbacks para entrenamiento
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    os.path.join(BASE_PATH, 'best_mini_xception_manual_weights_48x48.h5'),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    mode='max',
    restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

# %%
# Entrenar el modelo
steps_per_epoch = train_generator.n // BATCH_SIZE

history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // BATCH_SIZE,
    class_weight=class_weights_dict,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
# 717/717 [==============================] - 872s 1s/step - loss: 3.2640 - accuracy: 0.1824 - val_loss: 1.9119 - val_accuracy: 0.1617 - lr: 0.0010
# Epoch 2/50
# 717/717 [==============================] - 845s 1s/step - loss: 3.1726 - accuracy: 0.2178 - val_loss: 1.8461 - val_accuracy: 0.1887 - lr: 0.0010
# Epoch 3/50
# 717/717 [==============================] - 839s 1s/step - loss: 3.1116 - accuracy: 0.2361 - val_loss: 1.8289 - val_accuracy: 0.2226 - lr: 0.0010
# Epoch 4/50
# 717/717 [==============================] - 838s 1s/step - loss: 3.0873 - accuracy: 0.2480 - val_loss: 1.8591 - val_accuracy: 0.1905 - lr: 0.0010
# Epoch 5/50
# 717/717 [==============================] - 851s 1s/step - loss: 3.0628 - accuracy: 0.2621 - val_loss: 1.7788 - val_accuracy: 0.2874 - lr: 0.0010
# Epoch 6/50
# 717/717 [==============================] - 870s 1s/step - loss: 3.0391 - accuracy: 0.2690 - val_loss: 1.8089 - val_accuracy: 0.2591 - lr: 0.0010
# Epoch 7/50
# 717/717 [==============================] - 838s 1s/step - loss: 3.0337 - accuracy: 0.2762 - val_loss: 1.7878 - val_accuracy: 0.3050 - lr: 0.0010
# Epoch 8/50
# 717/717 [==============================] - 827s 1s/step - loss: 3.0202 - accuracy: 0.2840 - val_loss: 1.7901 - val_accuracy: 0.2826 - lr: 0.0010
# Epoch 9/50
# 717/717 [==============================] - 837s 1s/step - loss: 2.9995 - accuracy: 0.2874 - val_loss: 1.7599 - val_accuracy: 0.2992 - lr: 0.0010
# Epoch 10/50
# 717/717 [==============================] - 841s 1s/step - loss: 2.9937 - accuracy: 0.2847 - val_loss: 1.7358 - val_accuracy: 0.3038 - lr: 0.0010
# Epoch 11/50
# 717/717 [==============================] - 839s 1s/step - loss: 2.9902 - accuracy: 0.2943 - val_loss: 1.7872 - val_accuracy: 0.3142 - lr: 0.0010
# Epoch 12/50
# 717/717 [==============================] - 837s 1s/step - loss: 2.9678 - accuracy: 0.2933 - val_loss: 1.7679 - val_accuracy: 0.2973 - lr: 0.0010
# Epoch 13/50
# 717/717 [==============================] - 838s 1s/step - loss: 2.9602 - accuracy: 0.3111 - val_loss: 2.0810 - val_accuracy: 0.1968 - lr: 0.0010
# Epoch 14/50
# 717/717 [==============================] - 838s 1s/step - loss: 2.9445 - accuracy: 0.3119 - val_loss: 1.7870 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 15/50
# 717/717 [==============================] - 839s 1s/step - loss: 2.9187 - accuracy: 0.3107 - val_loss: 1.7105 - val_accuracy: 0.3108 - lr: 0.0010
# Epoch 16/50
# 717/717 [==============================] - 844s 1s/step - loss: 2.9114 - accuracy: 0.3262 - val_loss: 1.7090 - val_accuracy: 0.3326 - lr: 0.0010
# Epoch 17/50
# 717/717 [==============================] - 837s 1s/step - loss: 2.9104 - accuracy: 0.3251 - val_loss: 1.6866 - val_accuracy: 0.3319 - lr: 0.0010
# Epoch 18/50
# 717/717 [==============================] - 840s 1s/step - loss: 2.8782 - accuracy: 0.3291 - val_loss: 1.6403 - val_accuracy: 0.3649 - lr: 0.0010
# Epoch 19/50
# 717/717 [==============================] - 838s 1s/step - loss: 2.8837 - accuracy: 0.3320 - val_loss: 1.8174 - val_accuracy: 0.2767 - lr: 0.0010
# Epoch 20/50
# 717/717 [==============================] - 839s 1s/step - loss: 2.8661 - accuracy: 0.3467 - val_loss: 1.6339 - val_accuracy: 0.3687 - lr: 0.0010
# Epoch 21/50
# 717/717 [==============================] - 839s 1s/step - loss: 2.8388 - accuracy: 0.3508 - val_loss: 1.6574 - val_accuracy: 0.3507 - lr: 0.0010
# Epoch 22/50
# 717/717 [==============================] - 840s 1s/step - loss: 2.8149 - accuracy: 0.3587 - val_loss: 1.6276 - val_accuracy: 0.3492 - lr: 0.0010
# Epoch 23/50
# 717/717 [==============================] - 836s 1s/step - loss: 2.8182 - accuracy: 0.3614 - val_loss: 1.5891 - val_accuracy: 0.3729 - lr: 0.0010
# Epoch 24/50
# 717/717 [==============================] - 833s 1s/step - loss: 2.7880 - accuracy: 0.3689 - val_loss: 1.5659 - val_accuracy: 0.3949 - lr: 0.0010
# Epoch 25/50
# 717/717 [==============================] - 836s 1s/step - loss: 2.7855 - accuracy: 0.3702 - val_loss: 1.6012 - val_accuracy: 0.3780 - lr: 0.0010
# Epoch 26/50
# 717/717 [==============================] - 833s 1s/step - loss: 2.7626 - accuracy: 0.3760 - val_loss: 1.9689 - val_accuracy: 0.2577 - lr: 0.0010
# Epoch 27/50
# 717/717 [==============================] - 836s 1s/step - loss: 2.7599 - accuracy: 0.3808 - val_loss: 1.5744 - val_accuracy: 0.4007 - lr: 0.0010
# Epoch 28/50
# 717/717 [==============================] - 839s 1s/step - loss: 2.7472 - accuracy: 0.3831 - val_loss: 1.6077 - val_accuracy: 0.3829 - lr: 0.0010
# Epoch 29/50
# 717/717 [==============================] - 845s 1s/step - loss: 2.7377 - accuracy: 0.3877 - val_loss: 1.6263 - val_accuracy: 0.3596 - lr: 0.0010
# Epoch 30/50
# 717/717 [==============================] - 865s 1s/step - loss: 2.6864 - accuracy: 0.4015 - val_loss: 1.5506 - val_accuracy: 0.3902 - lr: 5.0000e-04
# Epoch 31/50
# 717/717 [==============================] - 864s 1s/step - loss: 2.6631 - accuracy: 0.4031 - val_loss: 1.5062 - val_accuracy: 0.4199 - lr: 5.0000e-04
# Epoch 32/50
# 717/717 [==============================] - 866s 1s/step - loss: 2.6527 - accuracy: 0.3994 - val_loss: 1.5426 - val_accuracy: 0.4035 - lr: 5.0000e-04
# Epoch 33/50
# 717/717 [==============================] - 869s 1s/step - loss: 2.6476 - accuracy: 0.4090 - val_loss: 1.5358 - val_accuracy: 0.4007 - lr: 5.0000e-04
# Epoch 34/50
# 717/717 [==============================] - 863s 1s/step - loss: 2.6370 - accuracy: 0.4094 - val_loss: 1.5021 - val_accuracy: 0.4181 - lr: 5.0000e-04
# Epoch 35/50
# 717/717 [==============================] - 863s 1s/step - loss: 2.6267 - accuracy: 0.4097 - val_loss: 1.5243 - val_accuracy: 0.4195 - lr: 5.0000e-04
# Epoch 36/50
# 717/717 [==============================] - 871s 1s/step - loss: 2.6302 - accuracy: 0.4116 - val_loss: 1.5358 - val_accuracy: 0.4106 - lr: 5.0000e-04
# Epoch 37/50
# 717/717 [==============================] - 868s 1s/step - loss: 2.6218 - accuracy: 0.4163 - val_loss: 1.4891 - val_accuracy: 0.4258 - lr: 5.0000e-04
# Epoch 38/50
# 717/717 [==============================] - 865s 1s/step - loss: 2.6140 - accuracy: 0.4160 - val_loss: 1.5206 - val_accuracy: 0.4199 - lr: 5.0000e-04
# Epoch 39/50
# 717/717 [==============================] - 862s 1s/step - loss: 2.6150 - accuracy: 0.4168 - val_loss: 1.5290 - val_accuracy: 0.4113 - lr: 5.0000e-04
# Epoch 40/50
# 717/717 [==============================] - 859s 1s/step - loss: 2.6021 - accuracy: 0.4208 - val_loss: 1.4832 - val_accuracy: 0.4092 - lr: 5.0000e-04
# Epoch 41/50
# 717/717 [==============================] - 862s 1s/step - loss: 2.5873 - accuracy: 0.4255 - val_loss: 1.5016 - val_accuracy: 0.4214 - lr: 5.0000e-04
# Epoch 42/50
# 717/717 [==============================] - 864s 1s/step - loss: 2.5870 - accuracy: 0.4210 - val_loss: 1.4546 - val_accuracy: 0.4441 - lr: 5.0000e-04
# Epoch 43/50
# 717/717 [==============================] - 862s 1s/step - loss: 2.5757 - accuracy: 0.4305 - val_loss: 1.5051 - val_accuracy: 0.4166 - lr: 5.0000e-04
# Epoch 44/50
# 717/717 [==============================] - 860s 1s/step - loss: 2.5635 - accuracy: 0.4224 - val_loss: 1.5459 - val_accuracy: 0.4024 - lr: 5.0000e-04
# Epoch 45/50
# 717/717 [==============================] - 864s 1s/step - loss: 2.5879 - accuracy: 0.4242 - val_loss: 1.4408 - val_accuracy: 0.4447 - lr: 5.0000e-04
# Epoch 46/50
# 717/717 [==============================] - 864s 1s/step - loss: 2.5621 - accuracy: 0.4305 - val_loss: 1.4948 - val_accuracy: 0.4251 - lr: 5.0000e-04
# Epoch 47/50
# 717/717 [==============================] - 863s 1s/step - loss: 2.5715 - accuracy: 0.4274 - val_loss: 1.4856 - val_accuracy: 0.4309 - lr: 5.0000e-04
# Epoch 48/50
# 717/717 [==============================] - 860s 1s/step - loss: 2.5518 - accuracy: 0.4338 - val_loss: 1.4441 - val_accuracy: 0.4324 - lr: 5.0000e-04
# Epoch 49/50
# 717/717 [==============================] - 863s 1s/step - loss: 2.5620 - accuracy: 0.4339 - val_loss: 1.6656 - val_accuracy: 0.3706 - lr: 5.0000e-04
# Epoch 50/50
# 717/717 [==============================] - 862s 1s/step - loss: 2.5591 - accuracy: 0.4329 - val_loss: 1.4321 - val_accuracy: 0.4518 - lr: 5.0000e-04

# %%
# Cargar el mejor modelo guardado
model.load_weights(os.path.join(BASE_PATH, 'best_mini_xception_manual_weights_48x48.h5'))

# %%
# Evaluar el modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 225/225 [==============================] - 7s 31ms/step - loss: 1.2913 - accuracy: 0.5057
# Test Loss: 1.2913
# Test Accuracy: 0.5057

# %%
# Obtener predicciones y etiquetas reales
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes
# Out:
# 225/225 [==============================] - 4s 16ms/step

# %%
# Calcular métricas con Scikit-learn
print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=CLASSES))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     surprise       0.57      0.78      0.66       831
#        happy       0.71      0.79      0.75      1774
#      neutral       0.42      0.69      0.52      1233
#        angry       0.36      0.27      0.31       958
#         fear       0.31      0.05      0.09      1024
#          sad       0.44      0.30      0.36      1247
#      disgust       0.17      0.44      0.24       111
#
#     accuracy                           0.51      7178
#    macro avg       0.42      0.47      0.42      7178
# weighted avg       0.48      0.51      0.47      7178

# %%
# Calcular F1-score promedio
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f"Weighted F1-Score: {f1:.4f}")
# Out:
# Weighted F1-Score: 0.4691

# %%
# Crear y mostrar la matriz de confusión
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Análisis de la matriz de confusión
print("Análisis de la matriz de confusión:")
for i, emotion in enumerate(CLASSES):
    true_positives = cm[i, i]
    false_positives = sum(cm[:, i]) - true_positives
    false_negatives = sum(cm[i, :]) - true_positives
    print(f"\n{emotion}:")
    print(f"  Verdaderos positivos: {true_positives}")
    print(f"  Falsos positivos: {false_positives}")
    print(f"  Falsos negativos: {false_negatives}")
    # Identificar clases con las que se confunde
    confusions = [(CLASSES[j], cm[i, j]) for j in range(len(CLASSES)) if j != i and cm[i, j] > 0]
    if confusions:
        print("  Se confunde con:")
        for conf_emotion, count in confusions:
            print(f"    - {conf_emotion}: {count} veces")
# Out:
# Análisis de la matriz de confusión:
#
# surprise:
#   Verdaderos positivos: 648
#   Falsos positivos: 494
#   Falsos negativos: 183
#   Se confunde con:
#     - happy: 58 veces
#     - neutral: 66 veces
#     - angry: 22 veces
#     - fear: 26 veces
#     - sad: 7 veces
#     - disgust: 4 veces
#
# happy:
#   Verdaderos positivos: 1397
#   Falsos positivos: 570
#   Falsos negativos: 377
#   Se confunde con:
#     - surprise: 83 veces
#     - neutral: 162 veces
#     - angry: 40 veces
#     - fear: 12 veces
#     - sad: 43 veces
#     - disgust: 37 veces
#
# neutral:
#   Verdaderos positivos: 853
#   Falsos positivos: 1200
#   Falsos negativos: 380
#   Se confunde con:
#     - surprise: 25 veces
#     - happy: 134 veces
#     - angry: 84 veces
#     - fear: 17 veces
#     - sad: 107 veces
#     - disgust: 13 veces
#
# angry:
#   Verdaderos positivos: 259
#   Falsos positivos: 454
#   Falsos negativos: 699
#   Se confunde con:
#     - surprise: 95 veces
#     - happy: 129 veces
#     - neutral: 243 veces
#     - fear: 27 veces
#     - sad: 120 veces
#     - disgust: 85 veces
#
# fear:
#   Verdaderos positivos: 51
#   Falsos positivos: 116
#   Falsos negativos: 973
#   Se confunde con:
#     - surprise: 247 veces
#     - happy: 99 veces
#     - neutral: 260 veces
#     - angry: 130 veces
#     - sad: 187 veces
#     - disgust: 50 veces
#
# sad:
#   Verdaderos positivos: 373
#   Falsos positivos: 474
#   Falsos negativos: 874
#   Se confunde con:
#     - surprise: 38 veces
#     - happy: 139 veces
#     - neutral: 460 veces
#     - angry: 158 veces
#     - fear: 28 veces
#     - disgust: 51 veces
#
# disgust:
#   Verdaderos positivos: 49
#   Falsos positivos: 240
#   Falsos negativos: 62
#   Se confunde con:
#     - surprise: 6 veces
#     - happy: 11 veces
#     - neutral: 9 veces
#     - angry: 20 veces
#     - fear: 6 veces
#     - sad: 10 veces
